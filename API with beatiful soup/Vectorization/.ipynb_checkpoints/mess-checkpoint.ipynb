# %%
import csv

csv_file = r'minerva_university_responses.csv'
txt_file = r'mu_responses_txt.txt'

with open(txt_file, "w", encoding="utf8") as my_output_file:
    with open(csv_file, "r", encoding="utf8") as my_input_file:
        [my_output_file.write(" ".join(row)+'\n') for row in csv.reader(x.replace('\0', '') for x in my_input_file)]
    my_output_file.close()

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.2.0-cp38-cp38-win_amd64.whl (24.0 MB)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\polin\anaconda3\lib\site-packages (from gensim) (1.7.3)
# Collecting Cython==0.29.28
#   Using cached Cython-0.29.28-py2.py3-none-any.whl (983 kB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-6.2.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\polin\anaconda3\lib\site-packages (from gensim) (1.19.5)
# Installing collected packages: Cython, smart-open, gensim
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.21
#     Uninstalling Cython-0.29.21:
#       Successfully uninstalled Cython-0.29.21
# Successfully installed Cython-0.29.28 gensim-4.2.0 smart-open-6.2.0

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings

warnings.filterwarnings(action='ignore')

import gensim
from gensim.models import Word2Vec

sample = open("mu_responses_txt.txt", encoding="utf8")
s = sample.read()
f = s.replace("\n", " ")
data = []
for i in sent_tokenize(f):
    temp = []

    # tokenize the sentence into words
    for j in word_tokenize(i):
        temp.append(j.lower())

    data.append(temp)
    
print(data)

# Create CBOW model
model1 = gensim.models.Word2Vec(data, min_count=1,
                                vector_size=100, window=5)
print("Cosine similarity between 'alice' " +
               "and 'wonderland' - CBOW : ",
    model1.wv.similarity('alice', 'wonderland'))

print("Cosine similarity between 'alice' " +
      "and 'machines' - CBOW : ",
      model1.wv.similarity('alice', 'machines'))

# Create Skip Gram model
model2 = gensim.models.Word2Vec(data, min_count=1, vector_size=100,
                                window=5, sg=1)

# Print results
print("Cosine similarity between 'network' " +
      "and 'node' - Skip Gram : ",
      model2.wv.similarity('network', 'node'))

print("Cosine similarity between 'network' " +
      "and 'system' - Skip Gram : ",
      model2.wv.similarity('network', 'system'))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Cosine similarity between 'alice' and 'wonderland' - CBOW :  0.5834716
# Cosine similarity between 'alice' and 'machines' - CBOW :  -0.005741832
# Cosine similarity between 'network' and 'node' - Skip Gram :  0.6329392
# Cosine similarity between 'network' and 'system' - Skip Gram :  0.7383011

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\polin\anaconda3\lib\site-packages (4.2.0)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\polin\anaconda3\lib\site-packages (from gensim) (1.7.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\polin\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: Cython==0.29.28 in c:\users\polin\anaconda3\lib\site-packages (from gensim) (0.29.28)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\polin\anaconda3\lib\site-packages (from gensim) (1.23.4)

# %%
import re
from nltk.stem.api import StemmerI
from nltk.stem.porter import *
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_colwidth', 100)
responses = pd.read_csv('minerva_university_responses.csv', encoding='latin-1')
#messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
#messages.columns = ["label", "text"]
responses.head()
# Out:
# C:\Users\Polin\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#    id  Polls ID  Assessment reports Student ID  \
# 0   1   12522.0                           41.0
# 1   2   12522.0                           42.0
# 2   3   12522.0                           44.0
# 3   4   12522.0                          237.0
# 4   5   12522.0                          239.0
#
#                                                                                Poll Responses Response  \
# 0  The strengths of Plato's approach is his construction of the whole framework (Matt answered this...
# 1   Having a difficulty with his Divided Line. The strength == that it clearly delineates the trans...
# 2  How can one know if he's in the cave or not, if one does not know, how will he get motivation an...
# 3  S: the hierarchy of the chart we filled out at the beginning of class: moral knowledge and objec...
# 4  It is difficult to grasp how to apply Plato's division of the intelligibel real into 2 parts to ...
#
#   Assessment reports Hashtag  Assessment reports Score
# 0         #objectivemorality                       2.0
# 1              #deductivearg                       2.0
# 2         #objectivemorality                       3.0
# 3         #objectivemorality                       3.0
# 4         #objectivemorality                       3.0

# %%
responses.dropna(subset = ['Poll Responses Response'], inplace=True)

# %%
responses['text_clean'] = responses['Poll Responses Response'].apply(lambda x: gensim.utils.simple_preprocess(x))
responses.head()
# Out:
#    id  Polls ID  Assessment reports Student ID  \
# 0   1   12522.0                           41.0
# 1   2   12522.0                           42.0
# 2   3   12522.0                           44.0
# 3   4   12522.0                          237.0
# 4   5   12522.0                          239.0
#
#                                                                                Poll Responses Response  \
# 0  The strengths of Plato's approach is his construction of the whole framework (Matt answered this...
# 1   Having a difficulty with his Divided Line. The strength == that it clearly delineates the trans...
# 2  How can one know if he's in the cave or not, if one does not know, how will he get motivation an...
# 3  S: the hierarchy of the chart we filled out at the beginning of class: moral knowledge and objec...
# 4  It is difficult to grasp how to apply Plato's division of the intelligibel real into 2 parts to ...
#
#   Assessment reports Hashtag  Assessment reports Score  \
# 0         #objectivemorality                       2.0
# 1              #deductivearg                       2.0
# 2         #objectivemorality                       3.0
# 3         #objectivemorality                       3.0
# 4         #objectivemorality                       3.0
#
#                                                                                             text_clean
# 0  [the, strengths, of, plato, approach, is, his, construction, of, the, whole, framework, matt, an...
# 1  [having, difficulty, with, his, divided, line, the, strength, that, it, clearly, delineates, the...
# 2  [how, can, one, know, if, he, in, the, cave, or, not, if, one, does, not, know, how, will, he, g...
# 3  [the, hierarchy, of, the, chart, we, filled, out, at, the, beginning, of, class, moral, knowledg...
# 4  [it, is, difficult, to, grasp, how, to, apply, plato, division, of, the, intelligibel, real, int...

# %%
# Encoding the label column
responses['Assessment reports Score']=responses['Assessment reports Score'].map({0:'N/A',1:'contains_nothing',2:'contains_some',3:'contains_enough',4:'contains_more_than_enough',5:'woof'})
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(responses['text_clean'], responses['Assessment reports Score'] , test_size=0.2)

# %%
# Train the word2vec model
w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100,
                                   window=5,
                                   min_count=2)

# %%
w2v_model.wv.index_to_key

# %%
# Find the most similar words to "king" based on word vectors from our trained model
w2v_model.wv.most_similar('systemdynamics')
# Out:
# [('multiplecauses', 0.7868876457214355),
#  ('multipleagents', 0.7522433400154114),
#  ('emotionaliq', 0.6934218406677246),
#  ('powerdynamics', 0.6752574443817139),
#  ('carrotandstick', 0.6680558919906616),
#  ('ethicalframing', 0.659713089466095),
#  ('levelofanalysis', 0.6281872987747192),
#  ('networks', 0.6254019737243652),
#  ('dynamics', 0.5965580940246582),
#  ('metacognition', 0.5944425463676453)]

# %%
df = pd.read_csv('minerva_university_responses.csv')
df.dropna(subset = ['Poll Responses Response'], inplace=True)
df_dict = {g: d for g, d in df.groupby('Assessment reports Hashtag')}
networks = df_dict['#networks']

# %%
networks['text_clean'] = networks['Poll Responses Response'].apply(lambda x: gensim.utils.simple_preprocess(x))

# %%
# Encoding the label column
networks['Assessment reports Score']=networks['Assessment reports Score'].map({0:'N/A',1:'contains_nothing',2:'contains_some',3:'contains_enough',4:'contains_more_than_enough',5:'woof'})
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(networks['text_clean'], networks['Assessment reports Score'] , test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text_clean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-7e394f4f344d> in <module>
#       2 networks['Assessment reports Score']=networks['Assessment reports Score'].map({0:'N/A',1:'contains_nothing',2:'contains_some',3:'contains_enough',4:'contains_more_than_enough',5:'woof'})
#       3 # Split data into train and test sets
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(networks['text_clean'], networks['Assessment reports Score'] , test_size=0.2)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
# -> 3083                 raise KeyError(key) from err
#    3084
#    3085         if tolerance is not None:
#
# KeyError: 'text_clean'

# %%
import re
from spacy.lang.en.stop_words import STOP_WORDS
from gensim.models.phrases import Phrases, Phraser

# %%
def get_sentences(input_file_pointer):
    while True:
        line = input_file_pointer.readline()
        if not line:
            break

        yield line

# %%
def clean_sentence(sentence):
    sentence = sentence.lower().strip()
    sentence = re.sub(r’[^a-z0-9\s]’, '’, sentence)
    return re.sub(r’\s{2,}’, ' ', sentence)
                      
def tokenize(sentence):
    return [token for token in sentence.split() if token not in STOP_WORDS]
                      
def build_phrases(sentences):
    phrases = Phrases(sentences,
                      min_count=5,
                      threshold=7,
                      progress_per=1000)
    return Phraser(phrases)

# %%
phrases_model.save('phrases_model.txt')
phrases_model= Phraser.load('phrases_model.txt')

# %%
def sentence_to_bi_grams(phrases_model, sentence):
    return ' '.join(phrases_model[sentence])

# %%
def sentences_to_bi_grams(n_grams, input_file_name, output_file_name):
    with open(input_file_name, 'r') as input_file_pointer:
        with open(output_file_name, 'w+') as out_file:
            for sentence in get_sentences(input_file_pointer):
                cleaned_sentence = clean_sentence(sentence)
                tokenized_sentence = tokenize(cleaned_sentence)
                parsed_sentence = sentence_to_bi_grams(n_grams, tokenized_sentence)
                out_file.write(parsed_sentence + '\n')

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from gensim.models import Doc2Vec
from sklearn import utils
from sklearn.model_selection import train_test_split
import gensim
from sklearn.linear_model import LogisticRegression
from gensim.models.doc2vec import TaggedDocument
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install scipy --upgrade --user
# Out:
# Requirement already up-to-date: scipy in c:\users\polin\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied, skipping upgrade: numpy<1.26.0,>=1.18.5 in c:\users\polin\anaconda3\lib\site-packages (from scipy) (1.23.4)

# %%
df = pd.read_csv('minerva_university_responses.csv')
df.dropna(subset = ['Poll Responses Response'], inplace=True)

df.head(10)
# Out:
#    id  Polls ID  Assessment reports Student ID  \
# 0   1   12522.0                           41.0
# 1   2   12522.0                           42.0
# 2   3   12522.0                           44.0
# 3   4   12522.0                          237.0
# 4   5   12522.0                          239.0
# 5   6   12522.0                          243.0
# 6   7   12522.0                          253.0
# 7   8   12522.0                          272.0
# 8   9   12522.0                          278.0
# 9  10   12522.0                          288.0
#
#                              Poll Responses Response  \
# 0  The strengths of Plato's approach is his const...
# 1   Having a difficulty with his Divided Line. Th...
# 2  How can one know if he's in the cave or not, i...
# 3  S: the hierarchy of the chart we filled out at...
# 4  It is difficult to grasp how to apply Plato's ...
# 5  Strenght: Plato does provide a framework for p...
# 6  We were arguing in my breakout about how we ca...
# 7  We neologised the term "caveception", meaning ...
# 8  Breakout group - Xiaoning claimed that we are ...
# 9  The most difficlut for me to grasp is how educ...
#
#   Assessment reports Hashtag  Assessment reports Score
# 0         #objectivemorality                       2.0
# 1              #deductivearg                       2.0
# 2         #objectivemorality                       3.0
# 3         #objectivemorality                       3.0
# 4         #objectivemorality                       3.0
# 5              #deductivearg                       3.0
# 6      #justificationmethods                       4.0
# 7         #objectivemorality                       3.0
# 8         #objectivemorality                       3.0
# 9              #deductivearg                       3.0

# %%
df.shape
# Out:
# (198080, 6)

# %%
df.index = range(198080)
df['Poll Responses Response'].apply(lambda x: len(x.split(' '))).sum()
# Out:
# 15380351

# %%
cnt_pro = df['Assessment reports Score'].value_counts()
plt.figure(figsize=(12,4))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Assessment reports Score', fontsize=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Polin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
cnt_pro = df['Assessment reports Hashtag'].value_counts()
plt.figure(figsize=(20,4))
sns.barplot(cnt_pro.index, cnt_pro.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Assessment reports Hashtag', fontsize=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Polin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\polin\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\polin\anaconda3\lib\site-packages (from bs4) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\polin\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)

# %%
from bs4 import BeautifulSoup
def cleanText(text):
    text = BeautifulSoup(text, "lxml").text
    text = re.sub(r'\|\|\|', r' ', text) 
    text = re.sub(r'http\S+', r'<URL>', text)
    text = text.lower()
    text = text.replace('x', '')
    return text
df['Poll Responses Response'] = df['Poll Responses Response'].apply(cleanText)
# Out:
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1OdIO3tDWB2xIU2a08bxahAS4n3EixhOsSfaGwg4qL4s/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/1DpSuYhUjBTtPmRhmHIzWRT17paiNjIFb5521oWwmwxQ/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/1uUl5f6WhGkefbkrsYRpgFyIIO-vc0jDLoNdstA6cXQI/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1v9pDRRrzPOFAAofGevOfoYtxgl4ru1q4crAgTbyPptI/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/14Nb84SOjRb7vnAAZHVgYHUb2-5cPZvR89yWU6qrwg7A/edit#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1pKGJjkrtKqFITU1LBN2mn1wIJDbp-pQ8-9thBrVBHLo/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1uGmsMYMWGhhsMDtvEPjH97dYmBQF6tuw5EWD99f-h10/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/1eG_GuHbNA7VGdZ5rzo_PHboe9zeVu_0AsbkaqiC0Kik/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1UEZwXcVkYoPLRUaq-FINnLQbiWyiOxAeckZU1T_F6Mc/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1-hOqZotEwEIKTuyBcPKRUJsTaO67qu5H-oeAXVIRTcI/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/1uNBqAAb09_jeF2V7QyZD4QpbUr9Gqk9y3-IJ4D5Pza4/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/1vYww7nuJ_yEWQDMDDL4I6pyqIInq5qxCkVXIhLeQlEE/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/10of04jAIdGZxSUSZPgFydCMvWwZ_YMLsNDB-rn0E_Jg/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/12WFM_CwW7DBVwSq1_cF3yZcWB4nxBCcie_4Sq3um7HI/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1rinNN2rnrHwSxjqZR7LK2pThxpu19MyzZfe-0nN4FCw/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/14M6kPwRPfnPc-B2GkxSZ_T3XwedjwB81qZ1VJUfXv6g/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1R6Bhkm7Q0XAXoY96yzy-x9HCUlQZ9xFhD8_GARA15GM/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1q_oRIHUcQOVMHKnfx29exn4x6NelIE2b4U-Kwf3wLnw/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1py7yQ4R7Ex4Q3Xf7XwVuOT_GjyHq_8NdhaTnimzZsuM/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/19fp9vhn8WQxj2q5bIQVn1jGtJxn_R7r_Oqw9m25f_WM/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/1fj7jEyHoXg3Co4TkNOFZV2WujAjqCtoB6SAXqf7AnRM/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/1Vr3rbI7Lq5WRYPGsWO4ck3HcYXy-uuO42pQxLJOer84/edit?usp=sharing" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/1NQwDuZB-R4NZ1k_ybnbQn3AcAfuEgZskt1BdgRv7XUo/edit" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/document/d/17qE1oGUiXPcmrooceMwuUi5NOadfSa5t7Al3nMFHhbo" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# C:\Users\Polin\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://docs.google.com/a/minerva.kgi.edu/document/d/
apply(
    lambda r: TaggedDocument(words=tokenize_text(r['Poll Responses Response']), tags=[r['Assessment reports Hashtag']]), axis=1)
test_tagged = test.apply(
    lambda r: TaggedDocument(words=tokenize_text(r['Poll Responses Response']), tags=[r['Assessment reports Hashtag']]), axis=1)

# %%
train_tagged.values[30]
# Out:
# TaggedDocument(words=['think', 'that', 'we', 'touched', 'upon', 'constraints', 'and', 'utility', 'in', 'today', "'s", 'class', 'for', 'constraints', 'we', 'see', 'that', 'in', 'the', 'conventional', 'method', 'to', 'reduce', 'the', 'imbalance', 'problem', 'there', 'is', 'no', 'formal', 'mathematical', 'way', 'that', 'can', 'represents', 'the', 'subjective', "'realness", 'of', 'picture', 'the', 'blue', 'bedsheet', 'should', 'be', 'real', 'but', 'math-wise', 'are', 'the', 'opposite', 'numbers', 'from', 'red', 'bedsheet', 'therefore', 'one', 'constraint', 'satisfaction', 'is', 'to', 'use', 'another', 'neural', 'network', 'to', 'approimate', 'human', 'judgements', 'that', 'is', 'more', 'efficient', 'and', 'less', 'costly', 'than', 'an', 'actual', 'human', 'in', 'the', 'use', 'of', 'gan', 'solution', 'the', 'utility', 'is', 'applied', 'bc', 'the', 'cost', 'of', 'having', 'false', 'neg'], tags=['#constraints'])

# %%
import multiprocessing
cores = multiprocessing.cpu_count()

# %%
model_dbow = Doc2Vec(dm=0, vector_size=300, negative=5, hs=0, min_count=2, sample = 0, workers=cores)
model_dbow.build_vocab([x for x in tqdm(train_tagged.values)])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 842235.67it/s]

# %%
# %%time
for epoch in range(30):
    model_dbow.train(utils.shuffle([x for x in tqdm(train_tagged.values)]), total_examples=len(train_tagged.values), epochs=1)
    model_dbow.alpha -= 0.002
    model_dbow.min_alpha = model_dbow.alpha
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 470250.15it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1281150.41it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 782177.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 670128.22it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 542548.07it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 850894.93it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 644629.52it/s]
# 100%|██████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 504531.09it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1590715.03it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1732788.52it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1529936.06it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1249165.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1215890.76it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1133653.57it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 2065951.74it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1541330.07it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 2233705.83it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 2438276.06it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1936350.40it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1982327.79it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1392417.42it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1995420.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1249340.31it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1796263.38it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1904074.93it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1725954.11it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1327226.46it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 2039449.76it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 2193733.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 138656/138656 [00:00<00:00, 1248704.55it/s]
# Wall time: 10min 25s

# %%
def vec_for_learning(model, tagged_docs):
    sents = tagged_docs.values
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words)) for doc in sents])
    return targets, regressors

# %%
y_train, X_train = vec_for_learning(model_dbow, train_tagged)
y_test, X_test = vec_for_learning(model_dbow, test_tagged)
#model = LogisticRegression()

logreg = LogisticRegression(n_jobs=1, C=1e5, solver='liblinear')
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

from sklearn.metrics import accuracy_score, f1_score
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))

# %%
# Initially, this model converted the data into a vector and then tried to predict the score from the vector.
# Now, it tries to predict the HC score
# What I want to test though, is how well the model makes itself a vector.

# %%
model_dmm = Doc2Vec(dm=1, dm_mean=1, vector_size=300, window=10, negative=5, min_count=1, workers=5, alpha=0.065, min_alpha=0.065)
model_dmm.build_vocab([x for x in tqdm(train_tagged.values)])

# %%
# %%time
for epoch in range(30):
    model_dmm.train(utils.shuffle([x for x in tqdm(train_tagged.values)]), total_examples=len(train_tagged.values), epochs=1)
    model_dmm.alpha -= 0.002
    model_dmm.min_alpha = model_dmm.alpha

# %%
y_train, X_train = vec_for_learning(model_dmm, train_tagged)
y_test, X_test = vec_for_learning(model_dmm, test_tagged)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))

# %%
model_dbow.delete_temporary_training_data(keep_doctags_vectors=True, keep_inference=True)
model_dmm.delete_temporary_training_data(keep_doctags_vectors=True, keep_inference=True)

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec
new_model = ConcatenatedDoc2Vec([model_dbow, model_dmm])

# %%
def get_vectors(model, tagged_docs):
    sents = tagged_docs.values
    targets, regressors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in sents])
    return targets, regressors

# %%
y_train, X_train = get_vectors(new_model, train_tagged)
y_test, X_test = get_vectors(new_model, test_tagged)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print('Testing accuracy %s' % accuracy_score(y_test, y_pred))
print('Testing F1 score: {}'.format(f1_score(y_test, y_pred, average='weighted')))
