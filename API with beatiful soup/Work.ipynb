# %%
# !pipenv install requests
# Out:
# Installing requests...
# Installing dependencies from Pipfile.lock (a290a1)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Creating a virtualenv for this project...
#
# Pipfile: C:\Users\saadi\Desktop\Minerva\Fall 2022\AI lab\Git\Research\API with beatiful soup\Pipfile
#
# Using C:/Users/saadi/AppData/Local/Programs/Python/Python310/python.exe (3.10.6) to create virtualenv...
#
#
# [    ] Creating virtual environment..
# [=   ] Creating virtual environment..
# [==  ] Creating virtual environment..
# [=== ] Creating virtual environment..
# [ ===] Creating virtual environment..
# [  ==] Creating virtual environment..
# [   =] Creating virtual environment..
# [    ] Creating virtual environment..
# [   =] Creating virtual environment..
# [  ==] Creating virtual environment..
# [ ===] Creating virtual environment..
# [====] Creating virtual environment..
# [=== ] Creating virtual environment..
# ...
